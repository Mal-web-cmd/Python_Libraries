# %% [markdown]
# <a href="https://colab.research.google.com/github/Mal-web-cmd/Python_Libraries/blob/main/ML_AI_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Importing Numpy

# %%
import numpy as np

# %% [markdown]
# 2.Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# 3.Importing for Visualisation

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 4.Reading the dataset into the python environment and showing the whole dataset in tabular form.

# %%
pd.read_csv("diabetes.csv")
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# 5.Naming the dataset

# %%
data_frame = pd.read_csv("diabetes.csv")

# %% [markdown]
# 6. Calculating the mean of the coloumn Pregnancy

# %%
data_frame.Pregnancies
data_frame.loc[:,'Pregnancies'].mean()
# Out:
# 3.8450520833333335

# %% [markdown]
# 7.Calculating the mean of the coloumn Glucose

# %%
data_frame.Glucose
data_frame.loc[:,'Glucose'].mean()
# Out:
# 120.89453125

# %% [markdown]
# 8.Calculating the mean of the coloumn BloodPressure

# %%
data_frame.BloodPressure
data_frame.loc[:,'BloodPressure'].mean()
# Out:
# 69.10546875

# %% [markdown]
# 9.Calculating the mean of the coloumn SkinThickness

# %%
data_frame.SkinThickness
data_frame.loc[:,'SkinThickness'].mean()
# Out:
# 20.536458333333332

# %% [markdown]
# 10.Calculating the mean of the coloumn Insulin

# %%
data_frame.Insulin
data_frame.loc[:,'Insulin'].mean()
# Out:
# 79.79947916666667

# %% [markdown]
# 11.Calculating the mean of the coloumn BMI

# %%
data_frame.BMI
data_frame.loc[:,'BMI'].mean()
# Out:
# 31.992578124999998

# %% [markdown]
# 12.Calculating the mean of the coloumn DiabetesPedigreeFunction

# %%
data_frame.DiabetesPedigreeFunction
data_frame.loc[:,'DiabetesPedigreeFunction'].mean()
# Out:
# 0.47187630208333325

# %% [markdown]
# 13.Calculating the mean of the coloumn Age

# %%
data_frame.Age
data_frame.loc[:,'Age'].mean()
# Out:
# 33.240885416666664

# %% [markdown]
# 14.Calculating the mean of the coloumn Outcome

# %%
data_frame.Outcome
data_frame.loc[:,'Outcome'].mean()
# Out:
# 0.3489583333333333

# %% [markdown]
# 15.a)Checking the null values

# %%
data_frame.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %% [markdown]
# 15.b)Checking the null values

# %%
data_frame.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# 16. Plotting a bar graph for Pregnancy and Glucose

# %%
plt.bar(data_frame.Pregnancies,data_frame.Glucose)
plt.show()

# %% [markdown]
# 17.Plotting a pie chart for BloodPressure

# %%
plt.pie(data_frame.BloodPressure)
plt.show()

# %% [markdown]
# 18.Line Graph of data set

# %%
data_frame.plot(  )
# Out:
# <Axes: >

# %% [markdown]
# 19. Line graph of Insulin and BMI

# %%
data_frame.plot(x = "Insulin", y = "BMI")
# Out:
# <Axes: xlabel='Insulin'>
